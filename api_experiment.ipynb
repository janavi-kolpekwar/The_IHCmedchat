# %%
from openai._client import OpenAI
import dotenv
import os

dotenv.load_dotenv()
# Out:
# True

# %%
client = OpenAI(api_key=os.getenv("OPEN_API_KEY"))

prompt = "What is the chemical formula for water?"

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": prompt
                }
            ]
        },
    ],

    # Optional parameters
    temperature=0.3, 
    max_tokens=1024, 
    top_p=1, 
    frequency_penalty=0.1, 
    presence_penalty=0.1,
)

print(response.choices[0].message.content)
# Out:
# The chemical formula for water is H₂O. This indicates that each molecule of water is composed of two hydrogen (H) atoms covalently bonded to one oxygen (O) atom.
